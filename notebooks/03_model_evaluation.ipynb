# %% [markdown]
# # JaksuHealth Model Evaluation
#
# Load the CSV files generated by `scripts/compare_models.py` and review
# the architecture comparison. This notebook does not contain fabricated
# metrics; run the evaluation scripts first.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
comparison = pd.read_csv(ROOT / "results" / "model_comparison.csv")
per_class = pd.read_csv(ROOT / "results" / "per_class_metrics.csv")
comparison

# %%
if not comparison.empty:
    comparison.set_index("model_name")[["macro_dice", "macro_iou"]].plot(
        kind="bar", ylim=(0, 1), figsize=(9, 5), title="Model comparison"
    )
